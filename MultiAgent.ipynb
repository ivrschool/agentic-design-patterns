# %%
from agentic_patterns.multiagent_pattern.agent import Agent

agent_example = Agent(
    name="Poet Agent",
    backstory="You are a well-known poet, who enjoys creating high quality poetry.",
    task_description="Write a poem about the meaning of life",
    task_expected_output="Just output the poem, without any title or introductory sentences",
)

# %%
print(agent_example.run())
# Out:
# In the grand tapestry of time and space,
# A question echoes, a haunting pace,
# What is the meaning that we all pursue,
# A mystery that only life can accrue.
#
# Like autumn leaves that rustle and fall,
# Our moments flee, beyond recall,
# Yet in their fleeting, fragile dance,
# We find the whispers of a cosmic trance.
#
# In love, in laughter, and in tears,
# We taste the depth of all our years,
# A kaleidoscope of joy and pain,
# A journey through the human heart's terrain.
#
# Perhaps the meaning lies not in the end,
# But in the beauty that our souls can mend,
# In every breath, a choice is made,
# To find the beauty, to love, to fade.
#
# For in the silence, when the noise subsides,
# We hear the whispers of our deepest tides,
# A call to live, to cherish every ray,
# To find the meaning in each new day.
#
# And when the final breath is drawn and still,
# The meaning of life is not a distant hill,
# But the sum of all the love we've known,
# The memories, the moments we've called home.

# %%
from agentic_patterns.tool_pattern.tool import tool

@tool
def write_str_to_txt(string_data: str, txt_filename: str):
    """
    Writes a string to a txt file.

    This function takes a string and writes it to a text file. If the file already exists, 
    it will be overwritten with the new data.

    Args:
        string_data (str): The string containing the data to be written to the file.
        txt_filename (str): The name of the text file to which the data should be written.
    """
    # Write the string data to the text file
    with open(txt_filename, mode='w', encoding='utf-8') as file:
        file.write(string_data)

    print(f"Data successfully written to {txt_filename}")

# %%
agent_tool_example = Agent(
    name="Writer Agent",
    backstory="You are a language model specialised in writing text into .txt files",
    task_description="Write the string 'This is a Tool Agent' into './tool_agent_example.txt'",
    task_expected_output="A .txt file containing the given string",
    tools=write_str_to_txt,
)

agent_tool_example.run()
# Out:
# []
# ['I need to write the given string into a txt file using the available tools.']
# ['\n{"name": "write_str_to_txt", "arguments": {"string_data": "This is a Tool Agent", "txt_filename": "./tool_agent_example.txt"}, "id": 0}\n']
#
# Thought: I need to write the given string into a txt file using the available tools.
#
# Using Tool: write_str_to_txt
#
# Tool call dict:
# {'name': 'write_str_to_txt', 'arguments': {'string_data': 'This is a Tool Agent', 'txt_filename': './tool_agent_example.txt'}, 'id': 0}
# Data successfully written to ./tool_agent_example.txt
#
# Tool result:
# None
#
# Observations: {0: None}
# ["A .txt file containing the string 'This is a Tool Agent' has been created"]
# "A .txt file containing the string 'This is a Tool Agent' has been created"

# %%
agent_1 = Agent(
    name="Poet Agent",
    backstory="You are a well-known poet, who enjoys creating high quality poetry.",
    task_description="Write a poem about the meaning of life",
    task_expected_output="Just output the poem, without any title or introductory sentences",
)

agent_2 = Agent(
    name="Poem Translator Agent",
    backstory="You are an expert translator especially skilled in Ancient Greek",
    task_description="Translate a poem into Ancient Greek", 
    task_expected_output="Just output the translated poem and nothing else"
)

# %%
agent_1 >> agent_2
# Out:
# Poem Translator Agent

# %%
print("Agent 1 dependencies: ", agent_1.dependencies)
print("Agent 1 dependents: ", agent_1.dependents)
print("Agent 2 dependencies: ", agent_2.dependencies)
print("Agent 2 dependents: ", agent_2.dependents)
# Out:
# Agent 1 dependencies:  []
# Agent 1 dependents:  [Poem Translator Agent]
# Agent 2 dependencies:  [Poet Agent]
# Agent 2 dependents:  []

# %%
print(agent_1.run())
# Out:
# In the grand tapestry of time and space,
# A thread of existence, a fleeting pace,
# We dance, we sing, we live, we grow,
# Searching for answers, as the moments flow.
#
# Like leaves on winds of change, we sway,
# Our paths, a journey, through life's maze,
# We seek, we find, we lose, we gain,
# And in the end, a legacy remains.
#
# In whispers of the heart, a truth is told,
# Of love, of hope, of dreams, of young and old,
# A symphony of souls, a chorus grand,
# Echoing through eternity's land.
#
# Through trials and tribulations, we find our way,
# Through darkness and light, a new dawn's ray,
# And as we wander, through life's plodding pace,
# We discover meaning, in every time and place.
#
# In the beauty of a sunrise, or a starry night,
# We find the magic, that makes life worthwhile and bright,
# A sense of purpose, that guides us along,
# A path that's winding, but never wrong.
#
# And when our time on earth, has come to an end,
# Our legacy remains, a story to amend,
# The meaning of life, a puzzle, we've tried to define,
# A mystery, that's ours, to make divine.

# %%
print(agent_2.context)  # The poem from agent_1 is now in agent_2's context
# Out:
# Poem Translator Agent received context:
# In the grand tapestry of time and space,
# A fleeting moment, a mortal's pace,
# A whispered question, an eternal sigh,
# What lies beyond, and why we try.
#
# A dance of atoms, a spark of soul,
# A flame that flickers, yet makes us whole,
# A tapestry rich, with threads of gold,
# Interwoven stories, yet to be told.
#
# In the depths of darkness, a light does shine,
# A beacon guiding, through the ebb and flow of time,
# A melody echoing, through the chambers of the heart,
# A harmony of love, that never departs.
#
# A journey winding, through mountains high and low,
# A path that's trodden, by the footsteps that we know,
# A mystery unfolding, like a rose in bloom,
# A beauty that's revealed, in the simplest of perfume.
#
# In the whispers of the wind, a truth is revealed,
# A secret that's hidden, yet in plain sight, unsealed,
# A meaning that's woven, into the fabric of our lives,
# A purpose that's waiting, like a door that opens wide.
#
# A symphony of moments, a kaleidoscope of sight,
# A dance of shadows, and the light that makes them bright,
# A story that's unfolding, like a river to the sea,
# A journey that's ending, yet forever meant to be.Poem Translator Agent received context:
# In the grand tapestry of time and space,
# A thread of existence, a fleeting pace,
# We dance, we sing, we live, we grow,
# Searching for answers, as the moments flow.
#
# Like leaves on winds of change, we sway,
# Our paths, a journey, through life's maze,
# We seek, we find, we lose, we gain,
# And in the end, a legacy remains.
#
# In whispers of the heart, a truth is told,
# Of love, of hope, of dreams, of young and old,
# A symphony of souls, a chorus grand,
# Echoing through eternity's land.
#
# Through trials and tribulations, we find our way,
# Through darkness and light, a new dawn's ray,
# And as we wander, through life's plodding pace,
# We discover meaning, in every time and place.
#
# In the beauty of a sunrise, or a starry night,
# We find the magic, that makes life worthwhile and bright,
# A sense of purpose, that guides us along,
# A path that's winding, but never wrong.
#
# And when our time on earth, has come to an end,
# Our legacy remains, a story to amend,
# The meaning of life, a puzzle, we've tried to define,
# A mystery, that's ours, to make divine.

# %%
print(agent_2.run())    # Translates the poem
# Out:
# Ἐν τῇ μεγάλῃ τοῦ χρόνου καὶ τοῦ chóρου tapētē,
# Μία ῥέουσα στιγμή, ἡ βίωσις ἡμῶν,
# Μία ψιθυρίζουσα ἐρώτησις, ἡ αἰώνιος ἔκστασις,
# Τί κεῖται πέρα, καὶ διὰ τί πειράζομεν.
#
# Ὁ χορὸς τῶν ἀτόμων, ἡ σπινθήρ τῆς ψυχῆς,
# Φλόγα ῥεПОῦσα, ἀλλὰ ἡμᾶς ὅλα ποιεῖ,
# Tapētē πλοῦτος, μετὰ ἱστορίας ἀργυροῦ,
# Διϋφασμενοὶ μύθοι, ἔτι ἀνακεκαλυμμένοι.
#
# Ἐν τῷ βυθῷ τοῦ σκότους, φῶς λάμπει,
# Ἡ διδάσκαλος ὁδηγός, διὰ ῥεύματος καὶ ῥοῆς τοῦ χρόνου,
# ᾨδή ἠχοῦσα, διὰ τῶν θαλάμων τῆς καρδίας,
# Ἁρμονία ἀγάπης, ἡ ὑμνοῦσα οὐδέποτε ἀποστρέφεται.
#
# Ὁδὸς ἑλισσόμενος, διὰ ὀρέων ὑψηλῶν καὶ ταπεινῶν,
# ΠCharacterSet βημάτων, ἡμῶν ποδῶν, ἡμῶν ὁδῶν,
# Μυστήριον ἀναπτύσσων, ὡσεί ῥόδον ἐν ἀνθήσει,
# Κάλλος ἀποκαλύπτον, ἐν τῷ ἁπίστῳ τοῦ ἀρώματος.
#
# Ἐν τοῖς ψιθύροις τοῦ ἀνέμου, ἀλήθεια ἀποκαλύπτεται,
# Κρύπτον μυστήριον, ἀλλὰ ἐν ἐ/remiai φανεροῦ,
# Νοήματα διαπλεκόμενα, εἰς τὸ ὕφασμα τῆς ζωῆς,
# Σκοπὸς προσδokalear, ὡσεί θύρα ἀνοίγουσα ἐν εὐρυχώρῳ.
#
# Συμφωνία στιγμῶν, διᾳδρομή ὀπτασίων,
# Χορὸς σκιῶν, καί το φῶς τὸ αὐτὰς ἐλάμπων,
# Μῦθος ἀναπτύσσων, ὡσεί ποταμὸς εἰς θάλασσαν,
# Ὁδὸς τελειοῦσα, ἀλλὰ ἀεὶ προορωμένη εἶναι.

# %% [markdown]
# # Create Crew

# %%
from agentic_patterns.multiagent_pattern.crew import Crew

with Crew() as crew:
    agent_1 = Agent(
        name="Poet Agent",
        backstory="You are a well-known poet, who enjoys creating high quality poetry.",
        task_description="Write a poem about the meaning of life",
        task_expected_output="Just output the poem, without any title or introductory sentences",
    )

    agent_2 = Agent(
        name="Poem Translator Agent",
        backstory="You are an expert translator especially skilled in Spanish",
        task_description="Translate a poem into Spanish", 
        task_expected_output="Just output the translated poem and nothing else"
    )

    agent_3 = Agent(
        name="Writer Agent",
        backstory="You are an expert transcriber, that loves writing poems into txt files",
        task_description="You'll receive a Spanish poem in your context. You need to write the poem into './poem.txt' file",
        task_expected_output="A txt file containing the greek poem received from the context",
        tools=write_str_to_txt,
    )

    agent_1 >> agent_2 >> agent_3

# %%
crew.plot()

# %%
crew.run()
# Out:
# ==================================================
# RUNNING AGENT: Poet Agent
# ==================================================
#
# In the grand tapestry of time and space,
# A thread of existence, a fleeting pace,
# We dance, we weave, we live, we grow,
# Seeking answers to the questions we know.
#
# Is it to love, to laugh, to cry, to be,
# To chase the dreams, to wild and carefree,
# To find the purpose, the meaning, the goal,
# To make a mark, to leave a soul?
#
# In the silence, we hear a whisper low,
# A call to journey, to explore, to know,
# The mysteries of the universe, the heart,
# The depths of human experience, a work of art.
#
# Through trials and tribulations, we find our way,
# Through darkness and light, we seize the day,
# We learn, we grow, we evolve, we become,
# A unique and precious thread in the cosmic loom.
#
# In the beauty of nature, we find our place,
# A sense of belonging, a sense of grace,
# A connection to the earth, the sun, the sea,
# A oneness with the universe, wild and free.
#
# And when our time on this earth is done,
# Our legacy remains, a memory, a sun,
# That shines for others, a guiding light,
# A beacon in the darkness, a gentle night.
#
# For the meaning of life is not just one thing,
# But a multitude of moments, a kaleidoscope of wings,
# It's the laughter, the tears, the joy, the strife,
# A complex and beautiful tapestry of human life.
#
# ==================================================
# RUNNING AGENT: Poem Translator Agent
# ==================================================
#
# En la gran tapecería de la existencia, somos solo un hilo,
# Un momento fugaz, una promesa susurrada, una vida no dicha.
# Buscamos significado, un propósito que reclamar,
# Una razón para levantarnos, para amar, para vivir, para soportar el peso de nuestro nombre.
#
# En los susurros del viento, escuchamos un llamado suave,
# Un faro en la oscuridad, una luz guiadora en todo.
# Una oportunidad para dejar nuestra huella, para hacer que nuestra presencia sea conocida,
# Para perseguir al sol, para bailar en la lluvia, para hacer que nuestro espíritu crezca.
#
# A través de pruebas y tribulaciones, encontramos nuestra fuerza interior,
# Una resolución para continuar, para perseverar, para alargar.
# El camino se retuerce y gira, un sendero sinuoso que recorremos,
# Sin embargo, en el silencio, descubrimos el verdadero hogar de nuestro corazón.
#
# En la belleza de la naturaleza, encontramos un reflejo de nuestra alma,
# Un espejo de nuestros deseos más profundos, una conexión que nos hace íntegros.
# El significado de la vida, un misterio para descifrar y compartir,
# Un rompecabezas con piezas que encajan, una historia que se escribe con cuidado.
#
# Está en el amor que damos, en la risa que creamos,
# En las lágrimas que secamos, en los recuerdos que cultivamos.
# Una vida con propósito, una vida con significado, una vida con fuerza,
# Un faro en la oscuridad, brillando con toda nuestra luz.
#
# En la gran tapecería del tiempo y el espacio,
# Un hilo de vida, un ritmo frágil y fugaz,
# Un baile de momentos, susurros del corazón,
# Una búsqueda de significado, una obra de arte.
#
# A través de pruebas y tribulaciones, encontramos nuestro camino,
# A través de la alegría y la tristeza, el día y la noche,
# Buscamos entender, agarrar y saber,
# El propósito de nuestra existencia, a medida que fluye.
#
# ¿Es para amar, para reír, para vivir y crecer?
# ¿Para dejar una huella, un legado que mostrar?
# ¿O es simplemente para ser, para respirar y ser libre?
# ¿Para encontrar nuestro propio camino, salvaje y sin cuidado?
#
# Quizás el significado de la vida no sea algo que encontremos,
# Sino algo que creamos, una historia que diseñamos,
# Una narrativa de momentos, de elecciones y de fuerza,
# Un testimonio del espíritu humano, brillando con intensidad.
#
# Al final, no son los años que vivimos,
# Sino la vida que vivimos en esos años, lo que damos,
# Un regalo para nosotros mismos, para los demás, y para el universo,
# Una gota de sabiduría, un rayo de esperanza, un verso.
#
# En la gran tapecería del tiempo y el espacio,
# Un pensamiento fugaz, un ritmo de un momento,
# Buscamos respuestas, noche y día,
# A la pregunta que nos persigue, "¿Cuál es el camino?"
#
# ¿Es para amar, para reír, para vivir y crecer,
# Para perseguir nuestros sueños, y dejar que nuestros espíritus brillen,
# ¿O es para buscar, para encontrar, para saber y entender,
# Los misterios que yacen, más allá de esta tierra mortal?
#
# Quizás sea para conectar, para tocar, para sentir y compartir,
# Para formar lazos que duran, y mostrar que nos importa,
# Para dejar una huella, un legado, un recuerdo que permanece,
# Largo después de que hemos partido, y nuestras llamas terrenales.
#
# O tal vez sea simplemente para existir, para respirar,
# Para empaparnos en la belleza, de la gran sinfonía de la vida,
# Para encontrar el significado, en lo mundano y lo común,
# Para descubrir la magia, que se esconde en cada refrán de un día ordinario.
#
# La respuesta yace, en el corazón y el alma,
# Una verdad personal, que nos hace íntegros,
# Es un viaje, no un destino, se nos dice,
# Un camino que se retuerce, a través de momentos, jóvenes y viejos.
#
# Así que dejamos que nos lleven, a través de los giros y las vueltas de la vida,
# Y encontremos nuestras propias, únicas y preciadas preocupaciones,
# Dejamos que apreciamos, cada respiración, cada momento que compartimos,
# Y hagamos lo máximo, del tiempo que tenemos, para mostrar que nos importa.
#
# En la gran tapecería del tiempo y el espacio,
# Un hilo de existencia, un ritmo fugaz,
# Bailamos, tejemos, vivimos, crecemos,
# Buscando respuestas a las preguntas que sabemos.
#
# ¿Es para amar, para reír, para llorar, para ser,
# Para perseguir los sueños, para ser salvaje y sin cuidado,
# Para encontrar el propósito, el significado, la meta,
# Para hacer una huella, para dejar un alma?
#
# En el silencio, escuchamos un susurro bajo,
# Un llamado a viajar, a explorar, a saber,
# Los misterios del universo, del corazón,
# Las profundidades de la experiencia humana, una obra de arte.
#
# A través de pruebas y tribulaciones, encontramos nuestro camino,
# A través de la oscuridad y la luz, agarramos el día,
# Aprendemos, crecemos, evolucionamos, nos convertimos,
# En un hilo único y precioso en el telar cósmico.
#
# En la belleza de la naturaleza, encontramos nuestro lugar,
# Un sentido de pertenencia, un sentido de gracia,
# Una conexión con la tierra, el sol, el mar,
# Una unicidad con el universo, salvaje y libre.
#
# Y cuando nuestro tiempo en esta tierra está terminado,
# Nuestro legado permanece, un recuerdo, un sol,
# Que brilla para los demás, una luz guiadora,
# Un faro en la oscuridad, una noche suave.
#
# Porque el significado de la vida no es solo una cosa,
# Sino una multitud de momentos, un kaleidoscopio de alas,
# Es la risa, las lágrimas, la alegría, la lucha,
# Una tapecería compleja y hermosa de la vida humana.
#
# ==================================================
# RUNNING AGENT: Writer Agent
# ==================================================
#
# []
# ["I need to write the given Spanish poem into a file named './poem.txt'"]
# ['\n{"name": "write_str_to_txt","arguments": {"string_data": "En la gran tapicer\\u00eda de la existencia, somos solo un hilo,\\nUn momento fugaz, una promesa susurrada, una vida no dicha.\\nBuscamos el significado, un prop\\u00f3sito que reclamar,\\nUna raz\\u00f3n para levantarnos, para amar, para vivir, para soportar el peso de nuestro nombre.\\n\\nEn los susurros del viento, o\\u00edmos un llamado suave,\\nUn faro en la oscuridad, una luz gu\\u00eda en todo.\\n Una oportunidad para dejar nuestra marca, para hacer conocida nuestra presencia,\\nPara perseguir el sol, para bailar en la lluvia, para hacer crecer nuestro esp\\u00edritu.\\n\\nA trav\\u00e9s de pruebas y tribulaciones, encontramos nuestra fuerza interior,\\nUna resoluci\\u00f3n para continuar, para perseverar, para alargar.\\nEl camino se retuerce y gira, un sendero sinuoso que recorremos,\\nSin embargo, en el silencio, descubrimos el verdadero hogar de nuestro coraz\\u00f3n.\\n\\nEn la belleza de la naturaleza, encontramos un reflejo de nuestro alma,\\nUn espejo de nuestros anhelos m\\u00e1s profundos, una conexi\\u00f3n que nos hace completos.\\nEl significado de la vida, un misterio para desentra\\u00f1ar y compartir,\\nUn rompecabezas con piezas que encajan, una historia que escribir con cuidado.\\n\\nEst\\u00e1 en el amor que damos, en la risa que creamos,\\nEn las l\\u00e1grimas que secamos, en los recuerdos que cultivamos.\\nUna vida con prop\\u00f3sito, una vida con significado, una vida con fuerza,\\nUn faro en la oscuridad, brillando con toute nuestra luz.\\n\\nEn la gran tapicer\\u00eda del tiempo y el espacio,\\nUn hilo de vida, un ritmo fr\\u00e1gil y fugaz,\\nUn baile de momentos, susurros del coraz\\u00f3n,\\nUna b\\u00f9squeda de significado, una obra de arte.\\n\\nA trav\\u00e9s de pruebas y tribulaciones, encontramos nuestro camino,\\nA trav\\u00e9s de la alegr\\u00eda y la tristeza, la noche y el d\\u00eda,\\nBuscamos entender, comprender y saber,\\nEl prop\\u00f3sito de nuestra existencia, mientras fluye y refluye.\\n\\n\\u00bfEs amar, re\\u00edr, vivir y crecer?\\n\\u00bfDejar una marca, un legado que mostrar?\\n\\u00bfO es simplemente ser, respirar y ser libre?\\n\\u00bfEncontrar nuestro propio camino, salvaje y sin cuidado?\\n\\nQuiz\\u00e1s el significado de la vida no es algo que encontremos,\\nsino algo que creamos, una historia que dise\\u00f1amos,\\nUna narrativa de momentos, de elecciones y de fuerza,\\nUn testimonio del esp\\u00edritu humano, brillando con intensidad.\\n\\nAl final, no son los a\\u00f1os que vivimos,\\nsino la vida que vivimos en esos a\\u00f1os, lo que damos,\\nUn regalo para nosotros mismos, para los dem\\u00e1s y para el universo,\\nUna gota de sabidur\\u00eda, un rayo de esperanza, un verso.\\n","txt_filename": "./poem.txt"}, "id": 0}\n']
#
# Thought: I need to write the given Spanish poem into a file named './poem.txt'
#
# Using Tool: write_str_to_txt
#
# Tool call dict:
# {'name': 'write_str_to_txt', 'arguments': {'string_data': 'En la gran tapicería de la existencia, somos solo un hilo,\nUn momento fugaz, una promesa susurrada, una vida no dicha.\nBuscamos el significado, un propósito que reclamar,\nUna razón para levantarnos, para amar, para vivir, para soportar el peso de nuestro nombre.\n\nEn los susurros del viento, oímos un llamado suave,\nUn faro en la oscuridad, una luz guía en todo.\n Una oportunidad para dejar nuestra marca, para hacer conocida nuestra presencia,\nPara perseguir el sol, para bailar en la lluvia, para hacer crecer nuestro espíritu.\n\nA través de pruebas y tribulaciones, encontramos nuestra fuerza interior,\nUna resolución para continuar, para perseverar, para alargar.\nEl camino se retuerce y gira, un sendero sinuoso que recorremos,\nSin embargo, en el silencio, descubrimos el verdadero hogar de nuestro corazón.\n\nEn la belleza de la naturaleza, encontramos un reflejo de nuestro alma,\nUn espejo de nuestros anhelos más profundos, una conexión que nos hace completos.\nEl significado de la vida, un misterio para desentrañar y compartir,\nUn rompecabezas con piezas que encajan, una historia que escribir con cuidado.\n\nEstá en el amor que damos, en la risa que creamos,\nEn las lágrimas que secamos, en los recuerdos que cultivamos.\nUna vida con propósito, una vida con significado, una vida con fuerza,\nUn faro en la oscuridad, brillando con toute nuestra luz.\n\nEn la gran tapicería del tiempo y el espacio,\nUn hilo de vida, un ritmo frágil y fugaz,\nUn baile de momentos, susurros del corazón,\nUna bùsqueda de significado, una obra de arte.\n\nA través de pruebas y tribulaciones, encontramos nuestro camino,\nA través de la alegría y la tristeza, la noche y el día,\nBuscamos entender, comprender y saber,\nEl propósito de nuestra existencia, mientras fluye y refluye.\n\n¿Es amar, reír, vivir y crecer?\n¿Dejar una marca, un legado que mostrar?\n¿O es simplemente ser, respirar y ser libre?\n¿Encontrar nuestro propio camino, salvaje y sin cuidado?\n\nQuizás el significado de la vida no es algo que encontremos,\nsino algo que creamos, una historia que diseñamos,\nUna narrativa de momentos, de elecciones y de fuerza,\nUn testimonio del espíritu humano, brillando con intensidad.\n\nAl final, no son los años que vivimos,\nsino la vida que vivimos en esos años, lo que damos,\nUn regalo para nosotros mismos, para los demás y para el universo,\nUna gota de sabiduría, un rayo de esperanza, un verso.\n', 'txt_filename': './poem.txt'}, 'id': 0}
# Data successfully written to ./poem.txt
#
# Tool result:
# None
#
# Observations: {0: None}
# ["The Spanish poem has been written to the './poem.txt' file"]
# The Spanish poem has been written to the './poem.txt' file
